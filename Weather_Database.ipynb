# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | marawi
# Processing Record 2 of Set 1 | kisangani
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | svecha
# Processing Record 6 of Set 1 | aykhal
# Processing Record 7 of Set 1 | atuona
# Processing Record 8 of Set 1 | deputatskiy
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | norman wells
# Processing Record 11 of Set 1 | paciran
# Processing Record 12 of Set 1 | vila velha
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | new norfolk
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | iquitos
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | ferme-neuve
# Processing Record 19 of Set 1 | paidha
# Processing Record 20 of Set 1 | maralal
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | upernavik
# Processing Record 23 of Set 1 | baie-comeau
# Processing Record 24 of Set 1 | road town
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | duncan
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | lima
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | sibolga
# Processing Record 35 of Set 1 | kilindoni
# Processing Record 36 of Set 1 | barrow
# Processing Record 37 of Set 1 | karatsu
# Processing Record 38 of Set 1 | jasper
# Processing Record 39 of Set 1 | dingle
# Processing Record 40 of Set 1 | khandyga
# Processing Record 41 of Set 1 | olafsvik
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | vanavara
# Processing Record 44 of Set 1 | tilichiki
# Processing Record 45 of Set 1 | morant bay
# Processing Record 46 of Set 1 | kupino
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 49 of Set 1 | coquimbo
# Processing Record 50 of Set 1 | aasiaat
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | roblin
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 2 | naryan-mar
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | namtsy
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 16 of Set 2 | provideniya
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | lavrentiya
# Processing Record 19 of Set 2 | abnub
# Processing Record 20 of Set 2 | inhambane
# Processing Record 21 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 2 | florenville
# Processing Record 23 of Set 2 | araouane
# Processing Record 24 of Set 2 | castro
# Processing Record 25 of Set 2 | menongue
# Processing Record 26 of Set 2 | los llanos de aridane
# Processing Record 27 of Set 2 | port arthur
# Processing Record 28 of Set 2 | bilibino
# Processing Record 29 of Set 2 | rocha
# Processing Record 30 of Set 2 | mount gambier
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | atambua
# Processing Record 33 of Set 2 | puerto escondido
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | talnakh
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | yelyzavethradka
# Processing Record 39 of Set 2 | bambous virieux
# Processing Record 40 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 2 | portland
# Processing Record 42 of Set 2 | santiago del estero
# Processing Record 43 of Set 2 | bathsheba
# Processing Record 44 of Set 2 | russell
# Processing Record 45 of Set 2 | eskilstuna
# Processing Record 46 of Set 2 | port moresby
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | bo
# City not found. Skipping...
# Processing Record 49 of Set 2 | ponta do sol
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | hualmay
# Processing Record 2 of Set 3 | klaksvik
# Processing Record 3 of Set 3 | buchanan
# Processing Record 4 of Set 3 | noumea
# Processing Record 5 of Set 3 | komsomolskiy
# Processing Record 6 of Set 3 | roncesvalles
# Processing Record 7 of Set 3 | dauriya
# Processing Record 8 of Set 3 | fare
# Processing Record 9 of Set 3 | vaini
# Processing Record 10 of Set 3 | thinadhoo
# Processing Record 11 of Set 3 | atoyac
# Processing Record 12 of Set 3 | artyom
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | beroroha
# Processing Record 15 of Set 3 | lebu
# Processing Record 16 of Set 3 | ahipara
# Processing Record 17 of Set 3 | mikuni
# Processing Record 18 of Set 3 | luderitz
# Processing Record 19 of Set 3 | namatanai
# Processing Record 20 of Set 3 | altay
# Processing Record 21 of Set 3 | bethel
# Processing Record 22 of Set 3 | grand-santi
# Processing Record 23 of Set 3 | mbandaka
# Processing Record 24 of Set 3 | lerwick
# Processing Record 25 of Set 3 | takoradi
# Processing Record 26 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 3 | harnosand
# Processing Record 28 of Set 3 | morros
# Processing Record 29 of Set 3 | grindavik
# Processing Record 30 of Set 3 | tual
# Processing Record 31 of Set 3 | codrington
# Processing Record 32 of Set 3 | puerto ayora
# Processing Record 33 of Set 3 | caxito
# Processing Record 34 of Set 3 | yulara
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | volchikha
# Processing Record 37 of Set 3 | dingzhou
# Processing Record 38 of Set 3 | georgetown
# Processing Record 39 of Set 3 | lowestoft
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 3 | bayanday
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | khatanga
# Processing Record 45 of Set 3 | villa maria
# Processing Record 46 of Set 3 | somerset
# Processing Record 47 of Set 3 | narsaq
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | buraydah
# Processing Record 50 of Set 3 | yashan
# Processing Record 1 of Set 4 | bonavista
# Processing Record 2 of Set 4 | hamilton
# Processing Record 3 of Set 4 | cherskiy
# Processing Record 4 of Set 4 | leh
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | kaitangata
# Processing Record 7 of Set 4 | viloco
# Processing Record 8 of Set 4 | alexandria
# Processing Record 9 of Set 4 | tasiilaq
# Processing Record 10 of Set 4 | gurskoye
# City not found. Skipping...
# Processing Record 11 of Set 4 | awjilah
# Processing Record 12 of Set 4 | sheridan
# Processing Record 13 of Set 4 | libenge
# Processing Record 14 of Set 4 | sur
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 4 | usinsk
# Processing Record 19 of Set 4 | acuna
# City not found. Skipping...
# Processing Record 20 of Set 4 | constitucion
# Processing Record 21 of Set 4 | sioux lookout
# Processing Record 22 of Set 4 | vardo
# Processing Record 23 of Set 4 | clyde river
# Processing Record 24 of Set 4 | sept-iles
# Processing Record 25 of Set 4 | fort nelson
# Processing Record 26 of Set 4 | merauke
# Processing Record 27 of Set 4 | leningradskiy
# Processing Record 28 of Set 4 | airai
# Processing Record 29 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 4 | ancud
# Processing Record 31 of Set 4 | kassala
# Processing Record 32 of Set 4 | fortuna
# Processing Record 33 of Set 4 | dunedin
# Processing Record 34 of Set 4 | port-cartier
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | mahesana
# Processing Record 37 of Set 4 | chirongui
# Processing Record 38 of Set 4 | mandera
# Processing Record 39 of Set 4 | timizart
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 4 | kavaratti
# Processing Record 43 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 4 | kodinsk
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | cabo san lucas
# Processing Record 48 of Set 4 | mezen
# Processing Record 49 of Set 4 | isangel
# Processing Record 50 of Set 4 | pokaran
# Processing Record 1 of Set 5 | moron
# Processing Record 2 of Set 5 | bairiki
# Processing Record 3 of Set 5 | kungurtug
# Processing Record 4 of Set 5 | paka
# Processing Record 5 of Set 5 | grootfontein
# Processing Record 6 of Set 5 | hami
# Processing Record 7 of Set 5 | esmeraldas
# Processing Record 8 of Set 5 | fort morgan
# Processing Record 9 of Set 5 | vostok
# Processing Record 10 of Set 5 | hambantota
# Processing Record 11 of Set 5 | bonthe
# Processing Record 12 of Set 5 | pimentel
# Processing Record 13 of Set 5 | xai-xai
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | srednekolymsk
# Processing Record 16 of Set 5 | umea
# Processing Record 17 of Set 5 | teguise
# Processing Record 18 of Set 5 | hirara
# Processing Record 19 of Set 5 | nichinan
# Processing Record 20 of Set 5 | agadez
# Processing Record 21 of Set 5 | brigantine
# Processing Record 22 of Set 5 | nome
# Processing Record 23 of Set 5 | severo-kurilsk
# Processing Record 24 of Set 5 | escanaba
# Processing Record 25 of Set 5 | paamiut
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | adrar
# Processing Record 28 of Set 5 | ribeira grande
# Processing Record 29 of Set 5 | dukat
# Processing Record 30 of Set 5 | touros
# Processing Record 31 of Set 5 | kavieng
# Processing Record 32 of Set 5 | cabedelo
# Processing Record 33 of Set 5 | porto novo
# Processing Record 34 of Set 5 | vilhena
# Processing Record 35 of Set 5 | honningsvag
# Processing Record 36 of Set 5 | japura
# Processing Record 37 of Set 5 | boddam
# Processing Record 38 of Set 5 | north bend
# Processing Record 39 of Set 5 | meadow lake
# Processing Record 40 of Set 5 | pravia
# Processing Record 41 of Set 5 | karratha
# Processing Record 42 of Set 5 | kahului
# Processing Record 43 of Set 5 | abu samrah
# Processing Record 44 of Set 5 | tripoli
# Processing Record 45 of Set 5 | victoria
# Processing Record 46 of Set 5 | paita
# Processing Record 47 of Set 5 | yongan
# Processing Record 48 of Set 5 | vestmanna
# Processing Record 49 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 5 | moose factory
# Processing Record 1 of Set 6 | nyimba
# Processing Record 2 of Set 6 | bandipur
# Processing Record 3 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 4 of Set 6 | oksfjord
# Processing Record 5 of Set 6 | lompoc
# Processing Record 6 of Set 6 | kirkwall
# Processing Record 7 of Set 6 | margate
# Processing Record 8 of Set 6 | mulege
# Processing Record 9 of Set 6 | kashan
# Processing Record 10 of Set 6 | saint-philippe
# Processing Record 11 of Set 6 | thunder bay
# Processing Record 12 of Set 6 | marsaxlokk
# Processing Record 13 of Set 6 | batetskiy
# Processing Record 14 of Set 6 | port macquarie
# Processing Record 15 of Set 6 | esperance
# Processing Record 16 of Set 6 | teguldet
# Processing Record 17 of Set 6 | vitim
# Processing Record 18 of Set 6 | saskylakh
# Processing Record 19 of Set 6 | svetlaya
# Processing Record 20 of Set 6 | port lincoln
# Processing Record 21 of Set 6 | okitipupa
# Processing Record 22 of Set 6 | geraldton
# Processing Record 23 of Set 6 | harlingen
# Processing Record 24 of Set 6 | mar del plata
# Processing Record 25 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 26 of Set 6 | praya
# Processing Record 27 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 6 | whitehorse
# Processing Record 29 of Set 6 | katherine
# Processing Record 30 of Set 6 | mpika
# Processing Record 31 of Set 6 | lazaro cardenas
# Processing Record 32 of Set 6 | maryborough
# Processing Record 33 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 6 | krutaya gorka
# Processing Record 36 of Set 6 | yumen
# Processing Record 37 of Set 6 | carnarvon
# Processing Record 38 of Set 6 | bo rai
# Processing Record 39 of Set 6 | mersing
# Processing Record 40 of Set 6 | seddon
# Processing Record 41 of Set 6 | san miguel
# Processing Record 42 of Set 6 | coihaique
# Processing Record 43 of Set 6 | kedrovyy
# Processing Record 44 of Set 6 | lujan
# Processing Record 45 of Set 6 | matipo
# Processing Record 46 of Set 6 | tongliao
# Processing Record 47 of Set 6 | shaoguan
# Processing Record 48 of Set 6 | xining
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | silver city
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | saint george
# Processing Record 3 of Set 7 | strezhevoy
# Processing Record 4 of Set 7 | maningrida
# Processing Record 5 of Set 7 | chokurdakh
# Processing Record 6 of Set 7 | chaiya
# Processing Record 7 of Set 7 | kuusamo
# Processing Record 8 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 9 of Set 7 | shizilu
# Processing Record 10 of Set 7 | lasa
# Processing Record 11 of Set 7 | collierville
# Processing Record 12 of Set 7 | saint-augustin
# Processing Record 13 of Set 7 | tomatlan
# Processing Record 14 of Set 7 | vestmannaeyjar
# Processing Record 15 of Set 7 | flinders
# Processing Record 16 of Set 7 | methoni
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | ostrovnoy
# Processing Record 19 of Set 7 | erice
# Processing Record 20 of Set 7 | trincomalee
# Processing Record 21 of Set 7 | santa barbara
# Processing Record 22 of Set 7 | safaga
# Processing Record 23 of Set 7 | bodden town
# Processing Record 24 of Set 7 | gorontalo
# Processing Record 25 of Set 7 | jericho
# Processing Record 26 of Set 7 | megion
# Processing Record 27 of Set 7 | krasnovishersk
# Processing Record 28 of Set 7 | kozhevnikovo
# Processing Record 29 of Set 7 | belmonte
# Processing Record 30 of Set 7 | sretensk
# Processing Record 31 of Set 7 | preobrazheniye
# Processing Record 32 of Set 7 | taoudenni
# Processing Record 33 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 7 | chegdomyn
# Processing Record 35 of Set 7 | bengkulu
# Processing Record 36 of Set 7 | morristown
# Processing Record 37 of Set 7 | kostino
# Processing Record 38 of Set 7 | luangwa
# Processing Record 39 of Set 7 | magugu
# Processing Record 40 of Set 7 | buon me thuot
# City not found. Skipping...
# Processing Record 41 of Set 7 | tecoanapa
# Processing Record 42 of Set 7 | novopavlovka
# Processing Record 43 of Set 7 | cap malheureux
# Processing Record 44 of Set 7 | berdigestyakh
# Processing Record 45 of Set 7 | souillac
# Processing Record 46 of Set 7 | pitimbu
# Processing Record 47 of Set 7 | mushie
# Processing Record 48 of Set 7 | ilulissat
# Processing Record 49 of Set 7 | mlimba
# Processing Record 50 of Set 7 | aitape
# Processing Record 1 of Set 8 | camacha
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 8 | maxixe
# Processing Record 6 of Set 8 | alofi
# Processing Record 7 of Set 8 | marsh harbour
# Processing Record 8 of Set 8 | gidole
# Processing Record 9 of Set 8 | sandwick
# Processing Record 10 of Set 8 | gairo
# Processing Record 11 of Set 8 | latung
# Processing Record 12 of Set 8 | rio verde de mato grosso
# Processing Record 13 of Set 8 | gazanjyk
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | barrancabermeja
# Processing Record 16 of Set 8 | makakilo city
# Processing Record 17 of Set 8 | am timan
# Processing Record 18 of Set 8 | talcahuano
# Processing Record 19 of Set 8 | nargana
# Processing Record 20 of Set 8 | san juan bautista
# Processing Record 21 of Set 8 | padang
# Processing Record 22 of Set 8 | veraval
# Processing Record 23 of Set 8 | san patricio
# Processing Record 24 of Set 8 | cam ranh
# Processing Record 25 of Set 8 | larsnes
# Processing Record 26 of Set 8 | nishihara
# Processing Record 27 of Set 8 | perth
# Processing Record 28 of Set 8 | severnyy-kospashskiy
# Processing Record 29 of Set 8 | praia da vitoria
# Processing Record 30 of Set 8 | krasnoye-na-volge
# Processing Record 31 of Set 8 | khammam
# Processing Record 32 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 8 | yablonovo
# Processing Record 34 of Set 8 | pangkalanbuun
# Processing Record 35 of Set 8 | erenhot
# Processing Record 36 of Set 8 | ust-nera
# Processing Record 37 of Set 8 | tateyama
# Processing Record 38 of Set 8 | nanortalik
# Processing Record 39 of Set 8 | misratah
# Processing Record 40 of Set 8 | riyadh
# Processing Record 41 of Set 8 | saldanha
# Processing Record 42 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 43 of Set 8 | zhigansk
# Processing Record 44 of Set 8 | young
# Processing Record 45 of Set 8 | naze
# Processing Record 46 of Set 8 | san carlos de bariloche
# Processing Record 47 of Set 8 | christchurch
# Processing Record 48 of Set 8 | egvekinot
# Processing Record 49 of Set 8 | castlemaine
# Processing Record 50 of Set 8 | aklavik
# Processing Record 1 of Set 9 | atakpame
# Processing Record 2 of Set 9 | mecca
# Processing Record 3 of Set 9 | getulio vargas
# Processing Record 4 of Set 9 | bafoulabe
# Processing Record 5 of Set 9 | farafangana
# Processing Record 6 of Set 9 | rock falls
# Processing Record 7 of Set 9 | karlskrona
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | morondava
# Processing Record 10 of Set 9 | tapes
# Processing Record 11 of Set 9 | omboue
# Processing Record 12 of Set 9 | sambava
# Processing Record 13 of Set 9 | nago
# Processing Record 14 of Set 9 | laguna
# Processing Record 15 of Set 9 | sorong
# Processing Record 16 of Set 9 | kieta
# Processing Record 17 of Set 9 | moerai
# Processing Record 18 of Set 9 | chekhov
# Processing Record 19 of Set 9 | olenegorsk
# Processing Record 20 of Set 9 | kizukuri
# Processing Record 21 of Set 9 | mehamn
# Processing Record 22 of Set 9 | tshikapa
# Processing Record 23 of Set 9 | biak
# Processing Record 24 of Set 9 | ngong
# Processing Record 25 of Set 9 | matola
# Processing Record 26 of Set 9 | amapa
# Processing Record 27 of Set 9 | saint-joseph
# Processing Record 28 of Set 9 | sturgis
# Processing Record 29 of Set 9 | college
# Processing Record 30 of Set 9 | sovetskaya
# Processing Record 31 of Set 9 | iqaluit
# Processing Record 32 of Set 9 | wanning
# Processing Record 33 of Set 9 | talaya
# Processing Record 34 of Set 9 | changping
# Processing Record 35 of Set 9 | witney
# Processing Record 36 of Set 9 | gambela
# Processing Record 37 of Set 9 | trelleborg
# Processing Record 38 of Set 9 | mareeba
# Processing Record 39 of Set 9 | baghdad
# Processing Record 40 of Set 9 | hovd
# Processing Record 41 of Set 9 | peterhead
# Processing Record 42 of Set 9 | ponta delgada
# Processing Record 43 of Set 9 | kropotkin
# Processing Record 44 of Set 9 | acarau
# Processing Record 45 of Set 9 | galle
# Processing Record 46 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 47 of Set 9 | vao
# Processing Record 48 of Set 9 | crib point
# Processing Record 49 of Set 9 | sangin
# Processing Record 50 of Set 9 | moses lake
# Processing Record 1 of Set 10 | kudahuvadhoo
# Processing Record 2 of Set 10 | roma
# Processing Record 3 of Set 10 | lethem
# Processing Record 4 of Set 10 | xiamen
# Processing Record 5 of Set 10 | maceio
# Processing Record 6 of Set 10 | shakawe
# Processing Record 7 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 9 of Set 10 | ketchikan
# Processing Record 10 of Set 10 | labuhan
# Processing Record 11 of Set 10 | yinchuan
# Processing Record 12 of Set 10 | macapa
# Processing Record 13 of Set 10 | sembakung
# Processing Record 14 of Set 10 | port hardy
# Processing Record 15 of Set 10 | alyangula
# Processing Record 16 of Set 10 | san cristobal
# Processing Record 17 of Set 10 | kusa
# Processing Record 18 of Set 10 | richards bay
# Processing Record 19 of Set 10 | cradock
# Processing Record 20 of Set 10 | schleiden
# Processing Record 21 of Set 10 | wilmington
# Processing Record 22 of Set 10 | rundu
# Processing Record 23 of Set 10 | dutse
# Processing Record 24 of Set 10 | visby
# Processing Record 25 of Set 10 | esna
# Processing Record 26 of Set 10 | byron bay
# Processing Record 27 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 28 of Set 10 | honiara
# Processing Record 29 of Set 10 | forasti
# Processing Record 30 of Set 10 | gushikawa
# Processing Record 31 of Set 10 | samarai
# Processing Record 32 of Set 10 | denpasar
# Processing Record 33 of Set 10 | bucak
# Processing Record 34 of Set 10 | duluth
# Processing Record 35 of Set 10 | donskoye
# Processing Record 36 of Set 10 | clarence town
# Processing Record 37 of Set 10 | olinda
# Processing Record 38 of Set 10 | mehriz
# Processing Record 39 of Set 10 | grahamstown
# Processing Record 40 of Set 10 | rapid valley
# Processing Record 41 of Set 10 | northam
# Processing Record 42 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 43 of Set 10 | boueni
# Processing Record 44 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 45 of Set 10 | kutoarjo
# Processing Record 46 of Set 10 | hostinne
# Processing Record 47 of Set 10 | waidhofen
# Processing Record 48 of Set 10 | namibe
# Processing Record 49 of Set 10 | general cepeda
# Processing Record 50 of Set 10 | marsa matruh
# Processing Record 1 of Set 11 | tonantins
# Processing Record 2 of Set 11 | oum hadjer
# Processing Record 3 of Set 11 | samana
# Processing Record 4 of Set 11 | muli
# Processing Record 5 of Set 11 | thanh hoa
# Processing Record 6 of Set 11 | moyale
# Processing Record 7 of Set 11 | launceston
# Processing Record 8 of Set 11 | berlevag
# Processing Record 9 of Set 11 | henties bay
# Processing Record 10 of Set 11 | farah
# Processing Record 11 of Set 11 | banda aceh
# Processing Record 12 of Set 11 | nanning
# Processing Record 13 of Set 11 | panguna
# Processing Record 14 of Set 11 | ocampo
# Processing Record 15 of Set 11 | sitka
# Processing Record 16 of Set 11 | saint anthony
# Processing Record 17 of Set 11 | dalvik
# Processing Record 18 of Set 11 | viedma
# Processing Record 19 of Set 11 | workington
# Processing Record 20 of Set 11 | quatre cocos
# Processing Record 21 of Set 11 | sinnamary
# Processing Record 22 of Set 11 | zhemchuzhnyy
# City not found. Skipping...
# Processing Record 23 of Set 11 | breves
# Processing Record 24 of Set 11 | paucartambo
# City not found. Skipping...
# Processing Record 25 of Set 11 | faanui
# Processing Record 26 of Set 11 | grand gaube
# Processing Record 27 of Set 11 | macklin
# Processing Record 28 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 29 of Set 11 | boquete
# Processing Record 30 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 11 | koplik
# Processing Record 32 of Set 11 | arman
# Processing Record 33 of Set 11 | chumikan
# Processing Record 34 of Set 11 | beyneu
# Processing Record 35 of Set 11 | te anau
# Processing Record 36 of Set 11 | bandarbeyla
# Processing Record 37 of Set 11 | cuaspud
# Processing Record 38 of Set 11 | nhulunbuy
# Processing Record 39 of Set 11 | praia
# Processing Record 40 of Set 11 | paralion astros
# City not found. Skipping...
# Processing Record 41 of Set 11 | tautira
# Processing Record 42 of Set 11 | burica
# City not found. Skipping...
# Processing Record 43 of Set 11 | clemson
# Processing Record 44 of Set 11 | belyy yar
# Processing Record 45 of Set 11 | kortkeros
# Processing Record 46 of Set 11 | inta
# Processing Record 47 of Set 11 | hokota
# Processing Record 48 of Set 11 | sao miguel do araguaia
# Processing Record 49 of Set 11 | nemuro
# Processing Record 50 of Set 11 | ciras
# City not found. Skipping...
# Processing Record 1 of Set 12 | boa vista
# Processing Record 2 of Set 12 | port hawkesbury
# Processing Record 3 of Set 12 | la massana
# Processing Record 4 of Set 12 | goderich
# Processing Record 5 of Set 12 | baruun-urt
# Processing Record 6 of Set 12 | naron
# Processing Record 7 of Set 12 | tabanan
# Processing Record 8 of Set 12 | mlowo
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | adelaide
# Processing Record 11 of Set 12 | oropoli
# Processing Record 12 of Set 12 | huarmey
# Processing Record 13 of Set 12 | shache
# Processing Record 14 of Set 12 | acapulco
# Processing Record 15 of Set 12 | faya
# Processing Record 16 of Set 12 | platon sanchez
# Processing Record 17 of Set 12 | seoul
# Processing Record 18 of Set 12 | kimbe
# Processing Record 19 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 20 of Set 12 | pisek
# Processing Record 21 of Set 12 | crotone
# Processing Record 22 of Set 12 | pervomayskiy
# Processing Record 23 of Set 12 | belozerskoye
# Processing Record 24 of Set 12 | kawalu
# Processing Record 25 of Set 12 | westport
# Processing Record 26 of Set 12 | buala
# Processing Record 27 of Set 12 | hobyo
# Processing Record 28 of Set 12 | torata
# Processing Record 29 of Set 12 | tongzi
# Processing Record 30 of Set 12 | shumskiy
# Processing Record 31 of Set 12 | karabulak
# Processing Record 32 of Set 12 | sarkand
# Processing Record 33 of Set 12 | chore
# City not found. Skipping...
# Processing Record 34 of Set 12 | abalak
# Processing Record 35 of Set 12 | zeya
# Processing Record 36 of Set 12 | mount isa
# Processing Record 37 of Set 12 | hailar
# Processing Record 38 of Set 12 | ivolginsk
# Processing Record 39 of Set 12 | zheleznodorozhnyy
# Processing Record 40 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 41 of Set 12 | iwaki
# Processing Record 42 of Set 12 | gaoyou
# Processing Record 43 of Set 12 | vila franca do campo
# Processing Record 44 of Set 12 | kant
# Processing Record 45 of Set 12 | singkang
# Processing Record 46 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 12 | dongkan
# Processing Record 49 of Set 12 | silifke
# Processing Record 50 of Set 12 | chapais
# Processing Record 1 of Set 13 | chulym
# Processing Record 2 of Set 13 | padilla
# Processing Record 3 of Set 13 | zabaykalsk
# Processing Record 4 of Set 13 | rincon viejo
# Processing Record 5 of Set 13 | necochea
# Processing Record 6 of Set 13 | kerki
# City not found. Skipping...
# Processing Record 7 of Set 13 | dudinka
# Processing Record 8 of Set 13 | tete
# Processing Record 9 of Set 13 | pangnirtung
# Processing Record 10 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 13 | camocim
# Processing Record 12 of Set 13 | liminangcong
# City not found. Skipping...
# Processing Record 13 of Set 13 | pilar
# Processing Record 14 of Set 13 | lodja
# Processing Record 15 of Set 13 | bubaque
# Processing Record 16 of Set 13 | keelung
# Processing Record 17 of Set 13 | uvira
# Processing Record 18 of Set 13 | tigil
# Processing Record 19 of Set 13 | goundam
# Processing Record 20 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 13 | tutla
# City not found. Skipping...
# Processing Record 22 of Set 13 | kloulklubed
# Processing Record 23 of Set 13 | svetlogorsk
# Processing Record 24 of Set 13 | burnie
# Processing Record 25 of Set 13 | cockburn town
# Processing Record 26 of Set 13 | zemio
# Processing Record 27 of Set 13 | mancio lima
# Processing Record 28 of Set 13 | bati
# Processing Record 29 of Set 13 | kenai
# Processing Record 30 of Set 13 | shahrud
# Processing Record 31 of Set 13 | lorengau
# Processing Record 32 of Set 13 | anadyr
# Processing Record 33 of Set 13 | atikokan
# Processing Record 34 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 35 of Set 13 | poso
# Processing Record 36 of Set 13 | otradnoye
# Processing Record 37 of Set 13 | ayagoz
# Processing Record 38 of Set 13 | fundacion
# Processing Record 39 of Set 13 | mudyuga
# City not found. Skipping...
# Processing Record 40 of Set 13 | chifeng
# Processing Record 41 of Set 13 | warren
# Processing Record 42 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 13 | amazar
# Processing Record 44 of Set 13 | plettenberg bay
# Processing Record 45 of Set 13 | cururupu
# Processing Record 46 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 13 | rach gia
# Processing Record 48 of Set 13 | asau
# Processing Record 49 of Set 13 | navoi
# Processing Record 50 of Set 13 | rio gallegos
# Processing Record 1 of Set 14 | ridgecrest
# Processing Record 2 of Set 14 | beauchamps
# Processing Record 3 of Set 14 | balkanabat
# Processing Record 4 of Set 14 | ulagan
# Processing Record 5 of Set 14 | torrelavega
# Processing Record 6 of Set 14 | gweta
# Processing Record 7 of Set 14 | jiexiu
# Processing Record 8 of Set 14 | lata
# Processing Record 9 of Set 14 | bobonong
# City not found. Skipping...
# Processing Record 10 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 14 | calabozo
# Processing Record 12 of Set 14 | liepaja
# Processing Record 13 of Set 14 | miram shah
# Processing Record 14 of Set 14 | salta
# Processing Record 15 of Set 14 | mattawa
# Processing Record 16 of Set 14 | concepcion del uruguay
# Processing Record 17 of Set 14 | pavlogradka
# Processing Record 18 of Set 14 | beringovskiy
# Processing Record 19 of Set 14 | maumelle
# Processing Record 20 of Set 14 | phalaborwa
# Processing Record 21 of Set 14 | mayo
# Processing Record 22 of Set 14 | guarapari
# Processing Record 23 of Set 14 | zyryanka
# Processing Record 24 of Set 14 | akyab
# Processing Record 25 of Set 14 | general roca
# Processing Record 26 of Set 14 | ceres
# Processing Record 27 of Set 14 | babol
# Processing Record 28 of Set 14 | itarema
# Processing Record 29 of Set 14 | riachao do dantas
# Processing Record 30 of Set 14 | majene
# Processing Record 31 of Set 14 | terrace
# Processing Record 32 of Set 14 | gizo
# Processing Record 33 of Set 14 | sibu
# Processing Record 34 of Set 14 | kinango
# Processing Record 35 of Set 14 | taunggyi
# Processing Record 36 of Set 14 | jiangyou
# Processing Record 37 of Set 14 | khor
# Processing Record 38 of Set 14 | galveston
# Processing Record 39 of Set 14 | jobabo
# Processing Record 40 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 14 | fairbanks
# Processing Record 42 of Set 14 | qaqortoq
# Processing Record 43 of Set 14 | ouadda
# Processing Record 44 of Set 14 | sistranda
# Processing Record 45 of Set 14 | havre-saint-pierre
# Processing Record 46 of Set 14 | santa marta
# Processing Record 47 of Set 14 | morehead
# Processing Record 48 of Set 14 | half moon bay
# Processing Record 49 of Set 14 | san jeronimo
# Processing Record 50 of Set 14 | barsovo
# Processing Record 1 of Set 15 | tromso
# Processing Record 2 of Set 15 | ixtapa
# Processing Record 3 of Set 15 | zalantun
# Processing Record 4 of Set 15 | sona
# Processing Record 5 of Set 15 | senno
# Processing Record 6 of Set 15 | cagliliog
# Processing Record 7 of Set 15 | curuca
# Processing Record 8 of Set 15 | belinskiy
# Processing Record 9 of Set 15 | trairi
# Processing Record 10 of Set 15 | gunjur
# Processing Record 11 of Set 15 | boyolangu
# Processing Record 12 of Set 15 | lluta
# Processing Record 13 of Set 15 | tiarei
# Processing Record 14 of Set 15 | torbay
# Processing Record 15 of Set 15 | jaguaribe
# Processing Record 16 of Set 15 | bozhou
# Processing Record 17 of Set 15 | pangai
# Processing Record 18 of Set 15 | jiuquan
# Processing Record 19 of Set 15 | bon accord
# Processing Record 20 of Set 15 | semey
# Processing Record 21 of Set 15 | sakaiminato
# Processing Record 22 of Set 15 | gao
# Processing Record 23 of Set 15 | abha
# Processing Record 24 of Set 15 | suchedniow
# Processing Record 25 of Set 15 | wladyslawowo
# Processing Record 26 of Set 15 | shingu
# Processing Record 27 of Set 15 | yingzhong
# City not found. Skipping...
# Processing Record 28 of Set 15 | emba
# Processing Record 29 of Set 15 | coahuayana
# Processing Record 30 of Set 15 | san quintin
# Processing Record 31 of Set 15 | pueblo nuevo
# Processing Record 32 of Set 15 | shimoda
# Processing Record 33 of Set 15 | moree
# Processing Record 34 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 35 of Set 15 | novikovo
# Processing Record 36 of Set 15 | esik
# Processing Record 37 of Set 15 | mao
# Processing Record 38 of Set 15 | ixmiquilpan
# Processing Record 39 of Set 15 | lakatoro
# Processing Record 40 of Set 15 | svetlyy
# Processing Record 41 of Set 15 | hillsboro
# Processing Record 42 of Set 15 | logansport
# Processing Record 43 of Set 15 | sabinas hidalgo
# Processing Record 44 of Set 15 | leshukonskoye
# Processing Record 45 of Set 15 | pueblo
# Processing Record 46 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 47 of Set 15 | kaoma
# Processing Record 48 of Set 15 | tamiami
# Processing Record 49 of Set 15 | manzanillo
# Processing Record 50 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 16 | dangriga
# Processing Record 2 of Set 16 | saint-pierre
# Processing Record 3 of Set 16 | lensk
# Processing Record 4 of Set 16 | garowe
# Processing Record 5 of Set 16 | birao
# Processing Record 6 of Set 16 | lolodorf
# Processing Record 7 of Set 16 | ostrov
# Processing Record 8 of Set 16 | buy
# Processing Record 9 of Set 16 | pak phanang
# Processing Record 10 of Set 16 | mufumbwe
# Processing Record 11 of Set 16 | waipawa
# Processing Record 12 of Set 16 | roald
# Processing Record 13 of Set 16 | potosi
# Processing Record 14 of Set 16 | nalus
# Processing Record 15 of Set 16 | yatou
# Processing Record 16 of Set 16 | taree
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Marawi   7.9986  124.2928     69.66        86          99
# 1     Kisangani   0.5167   25.2000     83.79        57          73
# 2  Punta Arenas -53.1500  -70.9167     46.51        71          75
# 3        Albany  42.6001  -73.9662     34.38        90          93
# 4        Svecha  58.2785   47.5164     21.69        94         100
# 5        Aykhal  66.0000  111.5000      4.30        95          98
# 6        Atuona  -9.8000 -139.0333     78.17        76          79
# 7   Deputatskiy  69.3000  139.9000     -9.74        92         100
# 8      Cidreira -30.1811  -50.2056     73.56        83           0
# 9  Norman Wells  65.2820 -126.8329    -15.65        92         100
#
#    Wind Speed Country                 Date
# 0        5.79      PH  2022-02-11 07:06:50
# 1        4.18      CD  2022-02-11 07:06:51
# 2       11.50      CL  2022-02-11 07:03:37
# 3        2.10      US  2022-02-11 07:06:51
# 4        7.18      RU  2022-02-11 07:06:52
# 5        7.96      RU  2022-02-11 07:06:52
# 6       17.74      PF  2022-02-11 07:06:53
# 7        4.65      RU  2022-02-11 07:06:53
# 8       18.28      BR  2022-02-11 07:06:10
# 9        2.42      CA  2022-02-11 07:02:29

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
