# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_current_weather = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Current Description": city_current_weather,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ecija
# Processing Record 2 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 1 | shellbrook
# Processing Record 4 of Set 1 | ribeira grande
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | lompoc
# Processing Record 7 of Set 1 | quang ngai
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | sao filipe
# Processing Record 11 of Set 1 | tazovskiy
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | nadym
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | dikson
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | pombas
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | cravo norte
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | vaini
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | guerrero negro
# Processing Record 27 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 1 | ostrovnoy
# Processing Record 29 of Set 1 | bam
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | waverly
# Processing Record 33 of Set 1 | new norfolk
# Processing Record 34 of Set 1 | acari
# Processing Record 35 of Set 1 | luwuk
# Processing Record 36 of Set 1 | kaeo
# Processing Record 37 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | pyay
# Processing Record 40 of Set 1 | vila franca do campo
# Processing Record 41 of Set 1 | cabo san lucas
# Processing Record 42 of Set 1 | mandalgovi
# Processing Record 43 of Set 1 | mwense
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | klaksvik
# Processing Record 46 of Set 1 | anadyr
# Processing Record 47 of Set 1 | ambilobe
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | bilibino
# Processing Record 50 of Set 1 | lindi
# Processing Record 1 of Set 2 | ugoofaaru
# Processing Record 2 of Set 2 | coquimbo
# Processing Record 3 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 2 | alice springs
# Processing Record 5 of Set 2 | capoterra
# Processing Record 6 of Set 2 | milingimbi
# City not found. Skipping...
# Processing Record 7 of Set 2 | abilene
# Processing Record 8 of Set 2 | yagoua
# Processing Record 9 of Set 2 | maxixe
# Processing Record 10 of Set 2 | otjimbingwe
# Processing Record 11 of Set 2 | maragogi
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | ahuimanu
# Processing Record 14 of Set 2 | calama
# Processing Record 15 of Set 2 | kapaa
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | pevek
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | bandarbeyla
# Processing Record 20 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 2 | abu kamal
# Processing Record 22 of Set 2 | takab
# Processing Record 23 of Set 2 | zhangjiakou
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | avera
# Processing Record 26 of Set 2 | prince rupert
# Processing Record 27 of Set 2 | vao
# Processing Record 28 of Set 2 | kahului
# Processing Record 29 of Set 2 | warrington
# Processing Record 30 of Set 2 | pangkalanbuun
# Processing Record 31 of Set 2 | seoul
# Processing Record 32 of Set 2 | lebu
# Processing Record 33 of Set 2 | yar-sale
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | pacific grove
# Processing Record 36 of Set 2 | pochutla
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | ketchikan
# Processing Record 39 of Set 2 | margate
# Processing Record 40 of Set 2 | mayo
# Processing Record 41 of Set 2 | mount gambier
# Processing Record 42 of Set 2 | pudozh
# Processing Record 43 of Set 2 | ponta delgada
# Processing Record 44 of Set 2 | yulara
# Processing Record 45 of Set 2 | morant bay
# Processing Record 46 of Set 2 | maine-soroa
# Processing Record 47 of Set 2 | bonthe
# Processing Record 48 of Set 2 | nanga eboko
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | kerman
# Processing Record 1 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 3 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | voh
# Processing Record 7 of Set 3 | aba
# Processing Record 8 of Set 3 | barrow
# Processing Record 9 of Set 3 | bethlehem
# Processing Record 10 of Set 3 | mataura
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | balkhash
# Processing Record 13 of Set 3 | omsukchan
# Processing Record 14 of Set 3 | bethel
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | saskylakh
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | puerto escondido
# Processing Record 19 of Set 3 | palana
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | imbituba
# Processing Record 22 of Set 3 | vallenar
# Processing Record 23 of Set 3 | makakilo city
# Processing Record 24 of Set 3 | norman wells
# Processing Record 25 of Set 3 | georgetown
# Processing Record 26 of Set 3 | mar del plata
# Processing Record 27 of Set 3 | neiafu
# Processing Record 28 of Set 3 | teguise
# Processing Record 29 of Set 3 | hasaki
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | thinadhoo
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | kaposvar
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | sioux lookout
# Processing Record 36 of Set 3 | manjacaze
# Processing Record 37 of Set 3 | toila
# Processing Record 38 of Set 3 | necochea
# Processing Record 39 of Set 3 | port elizabeth
# Processing Record 40 of Set 3 | paamiut
# Processing Record 41 of Set 3 | pandan
# Processing Record 42 of Set 3 | lumphat
# Processing Record 43 of Set 3 | belmonte
# Processing Record 44 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 46 of Set 3 | kalmunai
# Processing Record 47 of Set 3 | santa cruz
# Processing Record 48 of Set 3 | dunedin
# Processing Record 49 of Set 3 | fomboni
# Processing Record 50 of Set 3 | bantacan
# Processing Record 1 of Set 4 | qasigiannguit
# Processing Record 2 of Set 4 | sosnovskiy
# City not found. Skipping...
# Processing Record 3 of Set 4 | gamba
# Processing Record 4 of Set 4 | monticello
# Processing Record 5 of Set 4 | ndiekro
# City not found. Skipping...
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | rockland
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | severo-kurilsk
# Processing Record 11 of Set 4 | aykhal
# Processing Record 12 of Set 4 | wageningen
# Processing Record 13 of Set 4 | lavrentiya
# Processing Record 14 of Set 4 | minot
# Processing Record 15 of Set 4 | nevelsk
# Processing Record 16 of Set 4 | svetlaya
# Processing Record 17 of Set 4 | pundaguitan
# Processing Record 18 of Set 4 | la gaulette
# City not found. Skipping...
# Processing Record 19 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 4 | fairbanks
# Processing Record 21 of Set 4 | sistranda
# Processing Record 22 of Set 4 | ayaviri
# Processing Record 23 of Set 4 | tigil
# Processing Record 24 of Set 4 | bo rai
# Processing Record 25 of Set 4 | pangnirtung
# Processing Record 26 of Set 4 | kaitangata
# Processing Record 27 of Set 4 | cairns
# Processing Record 28 of Set 4 | oranjemund
# Processing Record 29 of Set 4 | port augusta
# Processing Record 30 of Set 4 | clyde river
# Processing Record 31 of Set 4 | byron bay
# Processing Record 32 of Set 4 | luganville
# Processing Record 33 of Set 4 | eyl
# Processing Record 34 of Set 4 | parabel
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | jasper
# Processing Record 37 of Set 4 | aksu
# Processing Record 38 of Set 4 | jujuy
# City not found. Skipping...
# Processing Record 39 of Set 4 | fjerritslev
# Processing Record 40 of Set 4 | lasa
# Processing Record 41 of Set 4 | tasiilaq
# Processing Record 42 of Set 4 | lusambo
# Processing Record 43 of Set 4 | puerto leguizamo
# Processing Record 44 of Set 4 | hermanus
# Processing Record 45 of Set 4 | srednekolymsk
# Processing Record 46 of Set 4 | teguldet
# Processing Record 47 of Set 4 | cape town
# Processing Record 48 of Set 4 | swan hill
# Processing Record 49 of Set 4 | ahipara
# Processing Record 50 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 1 of Set 5 | fort nelson
# Processing Record 2 of Set 5 | tres coracoes
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | sug-aksy
# City not found. Skipping...
# Processing Record 5 of Set 5 | suntar
# Processing Record 6 of Set 5 | oistins
# Processing Record 7 of Set 5 | carnarvon
# Processing Record 8 of Set 5 | half moon bay
# Processing Record 9 of Set 5 | kostomuksha
# Processing Record 10 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 11 of Set 5 | bardiyah
# Processing Record 12 of Set 5 | calvillo
# Processing Record 13 of Set 5 | bhawanipatna
# Processing Record 14 of Set 5 | airai
# Processing Record 15 of Set 5 | skjervoy
# Processing Record 16 of Set 5 | todos santos
# Processing Record 17 of Set 5 | okha
# Processing Record 18 of Set 5 | tahoua
# Processing Record 19 of Set 5 | thompson
# Processing Record 20 of Set 5 | yaremche
# Processing Record 21 of Set 5 | talcahuano
# Processing Record 22 of Set 5 | ciudad real
# Processing Record 23 of Set 5 | esperance
# Processing Record 24 of Set 5 | bowen
# Processing Record 25 of Set 5 | los llanos de aridane
# Processing Record 26 of Set 5 | hambantota
# Processing Record 27 of Set 5 | nikolskoye
# Processing Record 28 of Set 5 | chom bung
# City not found. Skipping...
# Processing Record 29 of Set 5 | am timan
# Processing Record 30 of Set 5 | canmore
# Processing Record 31 of Set 5 | mahebourg
# Processing Record 32 of Set 5 | novocheremshansk
# Processing Record 33 of Set 5 | san luis
# Processing Record 34 of Set 5 | iqaluit
# Processing Record 35 of Set 5 | luzhou
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 5 | belaya gora
# Processing Record 39 of Set 5 | bukachacha
# Processing Record 40 of Set 5 | inuvik
# Processing Record 41 of Set 5 | los mochis
# Processing Record 42 of Set 5 | nanortalik
# Processing Record 43 of Set 5 | vila velha
# Processing Record 44 of Set 5 | rodney
# Processing Record 45 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 46 of Set 5 | hobyo
# Processing Record 47 of Set 5 | havelock
# Processing Record 48 of Set 5 | hattiesburg
# Processing Record 49 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 5 | loreto
# Processing Record 1 of Set 6 | abbeville
# Processing Record 2 of Set 6 | konstantinovka
# Processing Record 3 of Set 6 | homer
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | grand-santi
# Processing Record 6 of Set 6 | chunskiy
# Processing Record 7 of Set 6 | saskatoon
# Processing Record 8 of Set 6 | saint george
# Processing Record 9 of Set 6 | prado
# Processing Record 10 of Set 6 | suslovo
# Processing Record 11 of Set 6 | tiksi
# Processing Record 12 of Set 6 | xining
# Processing Record 13 of Set 6 | nabire
# Processing Record 14 of Set 6 | vylkove
# Processing Record 15 of Set 6 | verkhnevilyuysk
# Processing Record 16 of Set 6 | phalombe
# Processing Record 17 of Set 6 | cherskiy
# Processing Record 18 of Set 6 | verkh-usugli
# Processing Record 19 of Set 6 | hamilton
# Processing Record 20 of Set 6 | birao
# Processing Record 21 of Set 6 | faya
# Processing Record 22 of Set 6 | batagay
# Processing Record 23 of Set 6 | lucapa
# Processing Record 24 of Set 6 | shimoda
# Processing Record 25 of Set 6 | samfya
# Processing Record 26 of Set 6 | elmadag
# Processing Record 27 of Set 6 | mount isa
# Processing Record 28 of Set 6 | shingu
# Processing Record 29 of Set 6 | arraial do cabo
# Processing Record 30 of Set 6 | dipkarpaz
# City not found. Skipping...
# Processing Record 31 of Set 6 | xai-xai
# Processing Record 32 of Set 6 | manggar
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 35 of Set 6 | matagami
# Processing Record 36 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 6 | taltal
# Processing Record 38 of Set 6 | te anau
# Processing Record 39 of Set 6 | roebourne
# Processing Record 40 of Set 6 | yueyang
# Processing Record 41 of Set 6 | camapua
# Processing Record 42 of Set 6 | paramonga
# Processing Record 43 of Set 6 | grand forks
# Processing Record 44 of Set 6 | jiroft
# City not found. Skipping...
# Processing Record 45 of Set 6 | koppang
# Processing Record 46 of Set 6 | umm kaddadah
# Processing Record 47 of Set 6 | burica
# City not found. Skipping...
# Processing Record 48 of Set 6 | sambava
# Processing Record 49 of Set 6 | biloela
# Processing Record 50 of Set 6 | antofagasta
# Processing Record 1 of Set 7 | igrim
# Processing Record 2 of Set 7 | vytegra
# Processing Record 3 of Set 7 | atherton
# Processing Record 4 of Set 7 | mecca
# Processing Record 5 of Set 7 | cururupu
# Processing Record 6 of Set 7 | satana
# Processing Record 7 of Set 7 | oda
# Processing Record 8 of Set 7 | whitecourt
# Processing Record 9 of Set 7 | sao gabriel da cachoeira
# Processing Record 10 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 7 | velikooktyabrskiy
# Processing Record 12 of Set 7 | yurino
# Processing Record 13 of Set 7 | smidovich
# Processing Record 14 of Set 7 | saint-augustin
# Processing Record 15 of Set 7 | dzhebariki-khaya
# Processing Record 16 of Set 7 | longyearbyen
# Processing Record 17 of Set 7 | chichi
# Processing Record 18 of Set 7 | formosa
# Processing Record 19 of Set 7 | torbay
# Processing Record 20 of Set 7 | bac lieu
# Processing Record 21 of Set 7 | portland
# Processing Record 22 of Set 7 | kenora
# Processing Record 23 of Set 7 | rumonge
# Processing Record 24 of Set 7 | santo domingo
# Processing Record 25 of Set 7 | natal
# Processing Record 26 of Set 7 | yanam
# Processing Record 27 of Set 7 | labrea
# Processing Record 28 of Set 7 | okhotsk
# Processing Record 29 of Set 7 | san jose
# Processing Record 30 of Set 7 | isangel
# Processing Record 31 of Set 7 | zelenogradsk
# Processing Record 32 of Set 7 | asau
# Processing Record 33 of Set 7 | camacha
# Processing Record 34 of Set 7 | rawson
# Processing Record 35 of Set 7 | carauari
# Processing Record 36 of Set 7 | bourail
# Processing Record 37 of Set 7 | sao felix do xingu
# Processing Record 38 of Set 7 | chuy
# Processing Record 39 of Set 7 | ardmore
# Processing Record 40 of Set 7 | salalah
# Processing Record 41 of Set 7 | palmer
# Processing Record 42 of Set 7 | flinders
# Processing Record 43 of Set 7 | morro bay
# Processing Record 44 of Set 7 | muros
# Processing Record 45 of Set 7 | kinablangan
# Processing Record 46 of Set 7 | saint anthony
# Processing Record 47 of Set 7 | bargarh
# Processing Record 48 of Set 7 | grenville
# Processing Record 49 of Set 7 | gwadar
# Processing Record 50 of Set 7 | koson
# Processing Record 1 of Set 8 | aleksandrov gay
# Processing Record 2 of Set 8 | namsos
# Processing Record 3 of Set 8 | komsomolskiy
# Processing Record 4 of Set 8 | pervomayskoye
# Processing Record 5 of Set 8 | waipawa
# Processing Record 6 of Set 8 | grand gaube
# Processing Record 7 of Set 8 | bom jesus
# Processing Record 8 of Set 8 | brae
# Processing Record 9 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 10 of Set 8 | nha trang
# Processing Record 11 of Set 8 | ciudad bolivar
# Processing Record 12 of Set 8 | rodbyhavn
# Processing Record 13 of Set 8 | kijang
# Processing Record 14 of Set 8 | kodiak
# Processing Record 15 of Set 8 | harper
# Processing Record 16 of Set 8 | egvekinot
# Processing Record 17 of Set 8 | shelburne
# Processing Record 18 of Set 8 | iwanai
# Processing Record 19 of Set 8 | bousse
# Processing Record 20 of Set 8 | oloron-sainte-marie
# Processing Record 21 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 8 | buchanan
# Processing Record 23 of Set 8 | el reno
# Processing Record 24 of Set 8 | namatanai
# Processing Record 25 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 8 | dicabisagan
# Processing Record 27 of Set 8 | havoysund
# Processing Record 28 of Set 8 | ormara
# Processing Record 29 of Set 8 | melhus
# Processing Record 30 of Set 8 | beyneu
# Processing Record 31 of Set 8 | narsaq
# Processing Record 32 of Set 8 | llandrindod wells
# Processing Record 33 of Set 8 | independence
# Processing Record 34 of Set 8 | east london
# Processing Record 35 of Set 8 | noumea
# Processing Record 36 of Set 8 | kanye
# Processing Record 37 of Set 8 | boissevain
# Processing Record 38 of Set 8 | sabha
# Processing Record 39 of Set 8 | tuktoyaktuk
# Processing Record 40 of Set 8 | lagoa
# Processing Record 41 of Set 8 | bengkulu
# Processing Record 42 of Set 8 | urumqi
# Processing Record 43 of Set 8 | colares
# Processing Record 44 of Set 8 | trairi
# Processing Record 45 of Set 8 | pinillos
# Processing Record 46 of Set 8 | kargasok
# Processing Record 47 of Set 8 | pedernales
# Processing Record 48 of Set 8 | balikpapan
# Processing Record 49 of Set 8 | surgut
# Processing Record 50 of Set 8 | mayor pablo lagerenza
# Processing Record 1 of Set 9 | lixourion
# Processing Record 2 of Set 9 | jacala
# Processing Record 3 of Set 9 | saint-joseph
# Processing Record 4 of Set 9 | santa rosa
# Processing Record 5 of Set 9 | codrington
# Processing Record 6 of Set 9 | gunjur
# Processing Record 7 of Set 9 | chokurdakh
# Processing Record 8 of Set 9 | kutum
# Processing Record 9 of Set 9 | forio
# Processing Record 10 of Set 9 | mitsamiouli
# Processing Record 11 of Set 9 | aswan
# Processing Record 12 of Set 9 | moron
# Processing Record 13 of Set 9 | jeremie
# Processing Record 14 of Set 9 | touros
# Processing Record 15 of Set 9 | quatre cocos
# Processing Record 16 of Set 9 | ulladulla
# Processing Record 17 of Set 9 | finschhafen
# Processing Record 18 of Set 9 | hakvik
# City not found. Skipping...
# Processing Record 19 of Set 9 | rodna
# Processing Record 20 of Set 9 | dasoguz
# Processing Record 21 of Set 9 | port said
# Processing Record 22 of Set 9 | uyuni
# Processing Record 23 of Set 9 | lady frere
# Processing Record 24 of Set 9 | naze
# Processing Record 25 of Set 9 | mao
# Processing Record 26 of Set 9 | fortuna
# Processing Record 27 of Set 9 | san antonio
# Processing Record 28 of Set 9 | vestmannaeyjar
# Processing Record 29 of Set 9 | lubyany
# Processing Record 30 of Set 9 | nishihara
# Processing Record 31 of Set 9 | puerto carreno
# Processing Record 32 of Set 9 | mahajanga
# Processing Record 33 of Set 9 | sandwick
# Processing Record 34 of Set 9 | port hardy
# Processing Record 35 of Set 9 | broken hill
# Processing Record 36 of Set 9 | izoplit
# Processing Record 37 of Set 9 | ponta do sol
# Processing Record 38 of Set 9 | armidale
# Processing Record 39 of Set 9 | pozo colorado
# Processing Record 40 of Set 9 | naples
# Processing Record 41 of Set 9 | belyy yar
# Processing Record 42 of Set 9 | forbes
# Processing Record 43 of Set 9 | naantali
# Processing Record 44 of Set 9 | dianopolis
# City not found. Skipping...
# Processing Record 45 of Set 9 | yian
# City not found. Skipping...
# Processing Record 46 of Set 9 | kloulklubed
# Processing Record 47 of Set 9 | middletown
# Processing Record 48 of Set 9 | beringovskiy
# Processing Record 49 of Set 9 | tacoronte
# Processing Record 50 of Set 9 | cidreira
# Processing Record 1 of Set 10 | soma
# Processing Record 2 of Set 10 | daru
# Processing Record 3 of Set 10 | gumdag
# Processing Record 4 of Set 10 | wajir
# Processing Record 5 of Set 10 | navrongo
# Processing Record 6 of Set 10 | asuncion
# Processing Record 7 of Set 10 | tilichiki
# Processing Record 8 of Set 10 | berdigestyakh
# Processing Record 9 of Set 10 | acarau
# Processing Record 10 of Set 10 | cap malheureux
# Processing Record 11 of Set 10 | laguna
# Processing Record 12 of Set 10 | gazojak
# Processing Record 13 of Set 10 | tarko-sale
# Processing Record 14 of Set 10 | lakhipur
# Processing Record 15 of Set 10 | grindavik
# Processing Record 16 of Set 10 | bubaque
# Processing Record 17 of Set 10 | ukiah
# Processing Record 18 of Set 10 | cayenne
# Processing Record 19 of Set 10 | koslan
# Processing Record 20 of Set 10 | vardo
# Processing Record 21 of Set 10 | itoman
# Processing Record 22 of Set 10 | tukrah
# Processing Record 23 of Set 10 | aylmer
# Processing Record 24 of Set 10 | ewa beach
# Processing Record 25 of Set 10 | magadan
# Processing Record 26 of Set 10 | zorgo
# Processing Record 27 of Set 10 | san quintin
# Processing Record 28 of Set 10 | qaqortoq
# Processing Record 29 of Set 10 | songjianghe
# Processing Record 30 of Set 10 | enniskerry
# Processing Record 31 of Set 10 | nome
# Processing Record 32 of Set 10 | beloha
# Processing Record 33 of Set 10 | marystown
# Processing Record 34 of Set 10 | derzhavinsk
# Processing Record 35 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 10 | boyolangu
# Processing Record 37 of Set 10 | arica
# Processing Record 38 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 10 | santa maria
# Processing Record 40 of Set 10 | strelka
# Processing Record 41 of Set 10 | tucuma
# Processing Record 42 of Set 10 | gberia fotombu
# Processing Record 43 of Set 10 | marshall
# Processing Record 44 of Set 10 | westport
# Processing Record 45 of Set 10 | jaguaruna
# Processing Record 46 of Set 10 | teya
# Processing Record 47 of Set 10 | la asuncion
# Processing Record 48 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 49 of Set 10 | tashtyp
# Processing Record 50 of Set 10 | adrar
# Processing Record 1 of Set 11 | huarmey
# Processing Record 2 of Set 11 | acapulco
# Processing Record 3 of Set 11 | floro
# Processing Record 4 of Set 11 | zhigansk
# Processing Record 5 of Set 11 | hervey bay
# Processing Record 6 of Set 11 | kavaratti
# Processing Record 7 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 11 | farah
# Processing Record 9 of Set 11 | kamenka
# Processing Record 10 of Set 11 | karratha
# Processing Record 11 of Set 11 | port hawkesbury
# Processing Record 12 of Set 11 | yelizovo
# Processing Record 13 of Set 11 | narsipatnam
# Processing Record 14 of Set 11 | saldanha
# Processing Record 15 of Set 11 | poya
# Processing Record 16 of Set 11 | ayan
# Processing Record 17 of Set 11 | coahuayana
# Processing Record 18 of Set 11 | ulaangom
# Processing Record 19 of Set 11 | kanniyakumari
# Processing Record 20 of Set 11 | trzebiatow
# Processing Record 21 of Set 11 | tornio
# Processing Record 22 of Set 11 | leua
# Processing Record 23 of Set 11 | axim
# Processing Record 24 of Set 11 | sibolga
# Processing Record 25 of Set 11 | carballo
# Processing Record 26 of Set 11 | yenagoa
# Processing Record 27 of Set 11 | barrancas
# Processing Record 28 of Set 11 | maniwaki
# Processing Record 29 of Set 11 | santa marta
# Processing Record 30 of Set 11 | kysyl-syr
# Processing Record 31 of Set 11 | bani walid
# Processing Record 32 of Set 11 | dingle
# Processing Record 33 of Set 11 | le vauclin
# Processing Record 34 of Set 11 | hoopstad
# Processing Record 35 of Set 11 | krasnogorsk
# Processing Record 36 of Set 11 | geraldton
# Processing Record 37 of Set 11 | nouadhibou
# Processing Record 38 of Set 11 | myrhorod
# Processing Record 39 of Set 11 | miranda
# Processing Record 40 of Set 11 | kvarkeno
# Processing Record 41 of Set 11 | pelym
# Processing Record 42 of Set 11 | caraballeda
# Processing Record 43 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 44 of Set 11 | vestmanna
# Processing Record 45 of Set 11 | chapais
# Processing Record 46 of Set 11 | mokhsogollokh
# Processing Record 47 of Set 11 | sfantu gheorghe
# Processing Record 48 of Set 11 | kimbe
# Processing Record 49 of Set 11 | hammerfest
# Processing Record 50 of Set 11 | gouyave
# Processing Record 1 of Set 12 | kita
# Processing Record 2 of Set 12 | svetlogorsk
# Processing Record 3 of Set 12 | tsabong
# Processing Record 4 of Set 12 | sakakah
# Processing Record 5 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 6 of Set 12 | ossora
# Processing Record 7 of Set 12 | punta de bombon
# Processing Record 8 of Set 12 | porteirinha
# Processing Record 9 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 10 of Set 12 | koumac
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | tabou
# Processing Record 13 of Set 12 | bone
# Processing Record 14 of Set 12 | xinzhou
# Processing Record 15 of Set 12 | sayat
# Processing Record 16 of Set 12 | coari
# Processing Record 17 of Set 12 | kuchera
# Processing Record 18 of Set 12 | goba
# Processing Record 19 of Set 12 | wyndham
# Processing Record 20 of Set 12 | aberdeen
# Processing Record 21 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 22 of Set 12 | roma
# Processing Record 23 of Set 12 | manbij
# Processing Record 24 of Set 12 | lalmohan
# Processing Record 25 of Set 12 | libreville
# Processing Record 26 of Set 12 | berlevag
# Processing Record 27 of Set 12 | tayga
# Processing Record 28 of Set 12 | shakiso
# Processing Record 29 of Set 12 | karia
# Processing Record 30 of Set 12 | dwarka
# Processing Record 31 of Set 12 | methoni
# Processing Record 32 of Set 12 | darhan
# Processing Record 33 of Set 12 | codajas
# Processing Record 34 of Set 12 | kailua
# Processing Record 35 of Set 12 | dharmabad
# Processing Record 36 of Set 12 | riva
# Processing Record 37 of Set 12 | selfoss
# Processing Record 38 of Set 12 | port blair
# Processing Record 39 of Set 12 | vanavara
# Processing Record 40 of Set 12 | rio grande
# Processing Record 41 of Set 12 | richards bay
# Processing Record 42 of Set 12 | pachperwa
# Processing Record 43 of Set 12 | dafeng
# Processing Record 44 of Set 12 | davila
# Processing Record 45 of Set 12 | kathmandu
# Processing Record 46 of Set 12 | litoral del san juan
# City not found. Skipping...
# Processing Record 47 of Set 12 | stolin
# Processing Record 48 of Set 12 | ozernovskiy
# Processing Record 49 of Set 12 | surab
# Processing Record 50 of Set 12 | ardakan
# Processing Record 1 of Set 13 | boddam
# Processing Record 2 of Set 13 | albina
# Processing Record 3 of Set 13 | banda aceh
# Processing Record 4 of Set 13 | nacozari
# Processing Record 5 of Set 13 | yurla
# Processing Record 6 of Set 13 | condado
# Processing Record 7 of Set 13 | mount pleasant
# Processing Record 8 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 9 of Set 13 | mantes-la-ville
# Processing Record 10 of Set 13 | petatlan
# Processing Record 11 of Set 13 | saint-francois
# Processing Record 12 of Set 13 | gus-zheleznyy
# Processing Record 13 of Set 13 | harindanga
# Processing Record 14 of Set 13 | laurel
# Processing Record 15 of Set 13 | shwebo
# Processing Record 16 of Set 13 | ulaanbaatar
# Processing Record 17 of Set 13 | falmouth
# Processing Record 18 of Set 13 | alghero
# Processing Record 19 of Set 13 | sao joao da barra
# Processing Record 20 of Set 13 | foshan
# Processing Record 21 of Set 13 | puerto madero
# Processing Record 22 of Set 13 | vila do maio
# Processing Record 23 of Set 13 | medford
# Processing Record 24 of Set 13 | dalby
# Processing Record 25 of Set 13 | svarstad
# Processing Record 26 of Set 13 | jatai
# Processing Record 27 of Set 13 | bathsheba
# Processing Record 28 of Set 13 | mafinga
# Processing Record 29 of Set 13 | lebedyn
# Processing Record 30 of Set 13 | dutse
# Processing Record 31 of Set 13 | haimen
# Processing Record 32 of Set 13 | glamoc
# Processing Record 33 of Set 13 | kaniv
# Processing Record 34 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 13 | labuhan
# Processing Record 36 of Set 13 | burladingen
# Processing Record 37 of Set 13 | tremedal
# Processing Record 38 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 13 | nemuro
# Processing Record 40 of Set 13 | havre
# Processing Record 41 of Set 13 | iquitos
# Processing Record 42 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 13 | port moresby
# Processing Record 44 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 13 | astoria
# Processing Record 46 of Set 13 | bonavista
# Processing Record 47 of Set 13 | tatvan
# Processing Record 48 of Set 13 | yershov
# Processing Record 49 of Set 13 | kismayo
# Processing Record 50 of Set 13 | issoire
# Processing Record 1 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 14 | hollola
# Processing Record 3 of Set 14 | sanmenxia
# Processing Record 4 of Set 14 | henties bay
# Processing Record 5 of Set 14 | samarai
# Processing Record 6 of Set 14 | erzin
# Processing Record 7 of Set 14 | bambous virieux
# Processing Record 8 of Set 14 | gusau
# Processing Record 9 of Set 14 | ilam
# Processing Record 10 of Set 14 | awbari
# Processing Record 11 of Set 14 | sorland
# Processing Record 12 of Set 14 | bundaberg
# Processing Record 13 of Set 14 | sisimiut
# Processing Record 14 of Set 14 | lalibela
# Processing Record 15 of Set 14 | tanout
# Processing Record 16 of Set 14 | tianpeng
# Processing Record 17 of Set 14 | kirakira
# Processing Record 18 of Set 14 | dunkwa
# Processing Record 19 of Set 14 | yeletskiy
# City not found. Skipping...
# Processing Record 20 of Set 14 | poum
# Processing Record 21 of Set 14 | chernyshevskiy
# Processing Record 22 of Set 14 | lakes entrance
# Processing Record 23 of Set 14 | viedma
# Processing Record 24 of Set 14 | general roca
# Processing Record 25 of Set 14 | lanigan
# Processing Record 26 of Set 14 | kirkuk
# Processing Record 27 of Set 14 | phuket
# Processing Record 28 of Set 14 | tessalit
# Processing Record 29 of Set 14 | luanda
# Processing Record 30 of Set 14 | venado tuerto
# Processing Record 31 of Set 14 | itarema
# Processing Record 32 of Set 14 | verkhnyaya inta
# Processing Record 33 of Set 14 | port hedland
# Processing Record 34 of Set 14 | suleja
# Processing Record 35 of Set 14 | pisco
# Processing Record 36 of Set 14 | talara
# Processing Record 37 of Set 14 | genhe
# Processing Record 38 of Set 14 | lahaina
# Processing Record 39 of Set 14 | kutulik
# Processing Record 40 of Set 14 | vostok
# Processing Record 41 of Set 14 | baghdad
# Processing Record 42 of Set 14 | hokitika
# Processing Record 43 of Set 14 | caravelas
# Processing Record 44 of Set 14 | ola
# Processing Record 45 of Set 14 | xuddur
# Processing Record 46 of Set 14 | nombre de dios
# Processing Record 47 of Set 14 | gat
# Processing Record 48 of Set 14 | smolenka
# Processing Record 49 of Set 14 | lorengau
# Processing Record 50 of Set 14 | kokopo
# Processing Record 1 of Set 15 | pahrump
# Processing Record 2 of Set 15 | tigpalay
# Processing Record 3 of Set 15 | shemordan
# Processing Record 4 of Set 15 | sechura
# Processing Record 5 of Set 15 | kiboga
# Processing Record 6 of Set 15 | safranbolu
# Processing Record 7 of Set 15 | agadez
# Processing Record 8 of Set 15 | damavand
# Processing Record 9 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 15 | yelyzavethradka
# Processing Record 11 of Set 15 | riyadh
# Processing Record 12 of Set 15 | dien bien
# City not found. Skipping...
# Processing Record 13 of Set 15 | namibe
# Processing Record 14 of Set 15 | mathathane
# Processing Record 15 of Set 15 | nhulunbuy
# Processing Record 16 of Set 15 | shasta lake
# Processing Record 17 of Set 15 | high wycombe
# Processing Record 18 of Set 15 | andros town
# Processing Record 19 of Set 15 | sandpoint
# Processing Record 20 of Set 15 | lasko
# Processing Record 21 of Set 15 | soverato
# Processing Record 22 of Set 15 | williams lake
# Processing Record 23 of Set 15 | erdenet
# Processing Record 24 of Set 15 | ust-ilimsk
# Processing Record 25 of Set 15 | yakima
# Processing Record 26 of Set 15 | la romana
# Processing Record 27 of Set 15 | college
# Processing Record 28 of Set 15 | wattegama
# Processing Record 29 of Set 15 | eydhafushi
# Processing Record 30 of Set 15 | yellandu
# Processing Record 31 of Set 15 | kalabo
# Processing Record 32 of Set 15 | tual
# Processing Record 33 of Set 15 | male
# Processing Record 34 of Set 15 | marang
# Processing Record 35 of Set 15 | markova
# Processing Record 36 of Set 15 | anloga
# Processing Record 37 of Set 15 | bazarnyye mataki
# Processing Record 38 of Set 15 | biltine
# Processing Record 39 of Set 15 | manokwari
# Processing Record 40 of Set 15 | nobres
# Processing Record 41 of Set 15 | kumylzhenskaya
# Processing Record 42 of Set 15 | kidal
# Processing Record 43 of Set 15 | kadyy
# Processing Record 44 of Set 15 | leningradskiy
# Processing Record 45 of Set 15 | aybak
# City not found. Skipping...
# Processing Record 46 of Set 15 | casper
# Processing Record 47 of Set 15 | gigmoto
# Processing Record 48 of Set 15 | brokopondo
# Processing Record 49 of Set 15 | horta
# Processing Record 50 of Set 15 | arecibo
# Processing Record 1 of Set 16 | penzance
# Processing Record 2 of Set 16 | honiara
# Processing Record 3 of Set 16 | batagay-alyta
# Processing Record 4 of Set 16 | hwange
# Processing Record 5 of Set 16 | halifax
# Processing Record 6 of Set 16 | weymouth
# Processing Record 7 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 16 | kings mountain
# Processing Record 9 of Set 16 | kristiinankaupunki
# Processing Record 10 of Set 16 | bohodukhiv
# Processing Record 11 of Set 16 | hualmay
# Processing Record 12 of Set 16 | puerto del rosario
# Processing Record 13 of Set 16 | port macquarie
# Processing Record 14 of Set 16 | malpe
# Processing Record 15 of Set 16 | natitingou
# Processing Record 16 of Set 16 | general pico
# Processing Record 17 of Set 16 | oktyabrskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0           Ecija  37.5422   -5.0826     54.75     overcast clouds        86
# 1      Shellbrook  53.2168 -106.4011     -2.97       broken clouds        99
# 2  Ribeira Grande  38.5167  -28.7000     61.36     overcast clouds        93
# 3            Hilo  19.7297 -155.0900     80.33           clear sky        70
# 4          Lompoc  34.6391 -120.4579     77.14           clear sky        44
# 5      Quang Ngai  15.1167  108.8000     74.28     overcast clouds        90
# 6         Qaanaaq  77.4840  -69.3632    -19.05           clear sky        48
# 7      Sao Filipe  14.8961  -24.4956     77.41     overcast clouds        48
# 8       Tazovskiy  67.4667   78.7000     -8.93           clear sky        90
# 9    Puerto Ayora  -0.7393  -90.3518     74.55    scattered clouds        94
#
#    Cloudiness  Wind Speed Country                 Date
# 0          95        3.42      ES  2022-02-13 01:41:24
# 1          60        6.40      CA  2022-02-13 01:41:25
# 2         100       15.19      PT  2022-02-13 01:41:25
# 3           0        9.22      US  2022-02-13 01:36:49
# 4           0        5.75      US  2022-02-13 01:41:26
# 5         100        3.06      VN  2022-02-13 01:41:26
# 6           0        8.77      GL  2022-02-13 01:41:27
# 7         100       18.99      CV  2022-02-13 01:41:28
# 8           7       15.52      RU  2022-02-13 01:41:28
# 9          42        1.01      EC  2022-02-13 01:41:29

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
